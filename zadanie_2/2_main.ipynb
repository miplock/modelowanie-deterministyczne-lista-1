# %% [markdown]
# # [Zadanie 1.](../zadanie_1/1_main.ipynb)

# %% [markdown]
# # Zadanie 2.

# %% [markdown]
# >Model logistyczny z odłowem proporcjonalnym do populacji dany jest równaniem
# >$$
# >\frac{dN}{dt} = rN\left(1-\frac NK\right) -kN,
# >$$
# >z parametrami $r>0, K>0$ oraz $k>0$.

# %% [markdown]
# ## 2.0.

# %% [markdown]
# >**Polecenie:** Opisz co oznaczają parametry modelu. Znajdź stany stacjonarne analitycznie. Przy jakich założeniach na parametry istnieją dwa stany stacjonarne?

# %% [markdown]
# [Rozwiązanie](./2_0.ipynb)

# %% [markdown]
# ## 2.1.

# %% [markdown]
# >**Polecenie:** Zaimplementuj Jawny Schemat Eulera (JSE) dla tego modelu.

# %% [markdown]
# [Rozwiązanie](./2_1.ipynb)

# %% [markdown]
# ## 2.2.

# %% [markdown]
# >**Polecenie:** Użyj parametru $K = 1$ i zbadaj relację "$r$ vs $k$": (a) $r = 1$, $k = 0.5$ oraz (b) $r = 1$, $k = 1.5$. Jak się zmieniają stany stacjonarne? Możesz posłużyć się wyprowadzeniem analitycznym.

# %% [markdown]
# [Rozwiązanie](./2_2.ipynb)

# %% [markdown]
# ## 2.3.

# %% [markdown]
# >**Polecenie:** Dla obu przypadków (a) i (b) przeprowadź symulacje dla kilku różnych wybranych przez siebie warunków początkowych. Czy rozwiązania zbiegają do stanu stacjonarnego?

# %% [markdown]
# [Rozwiązanie](./2_3.ipynb)

# %% [markdown]
# ## 2.4.

# %% [markdown]
# >**Polecenie:** Na podstawie symulacji pokaż, jak zmienia się stabilność stanu stacjonarnego $N^∗ = 0$ (z niestabilnego na stabilny), gdy $k$ przekracza $r$. Możesz posłużyć się obliczeniami analitycznymi.

# %% [markdown]
# [Rozwiązanie](./2_4.ipynb)

# %% [markdown]
# # 2.5.

# %% [markdown]
# >**Polecenie:** Dla $r = 1$ i $K = 1$, używając symulacji wynikających z JSE, wygeneruj wykres stanu stacjonarnego $N^∗$ w zależności od parametru odłowów $k \in [0, 2]$.

# %% [markdown]
# [Rozwiązanie](./2_5.ipynb)
