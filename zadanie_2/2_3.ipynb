# %% [markdown]
# [Powrót do zadania 2](./2_main.ipynb)
#
# [Poprzednie: 2.2.](./2_2.ipynb)

# %% [markdown]
# ## 2.3.

# %% [markdown]
# >**Polecenie:** Dla obu przypadków (a) i (b) przeprowadź symulacje dla kilku różnych wybranych przez siebie warunków początkowych. Czy rozwiązania zbiegają do stanu stacjonarnego?

# %% [markdown]
# **Rozwiązanie:**

# %%
import pickle

with open("zad_2_3_fig_1.pkl", "rb") as file:
    fig_1 = pickle.load(file)

fig_1.show()

# %% [markdown]
# W tym przypadku rozwiązania zbiegają do stanu stacjonarnego $N_2^*=0.5$.

# %%
with open("zad_2_3_fig_2.pkl", "rb") as file:
    fig_2 = pickle.load(file)

fig_2.show()

# %% [markdown]
# W tym przypadku rozwiązania zbiegają do stanu stacjonarnego $N_1^*=0$.

# %% [markdown]
# [Następne: 2.4.](./2_4.ipynb)
