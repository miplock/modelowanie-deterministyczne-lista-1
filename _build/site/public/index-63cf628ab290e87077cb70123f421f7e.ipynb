# %% [markdown]
# # Lista zadań 1
# ### Modelowanie deterministyczne
# #### Mikołaj Płóciniczak, 2025

# %%
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %% [markdown]
# # [Zadanie 1](./zadanie_1/1_main.ipynb)

# %% [markdown]
# # [Zadanie 2](./zadanie_2/2_main.ipynb)
